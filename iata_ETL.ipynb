# %%
# import etl libraries
import requests
import pandas as pd, numpy as np
from bs4 import BeautifulSoup

# %%
# fetch data
iata_data = pd.read_csv("data/country-development-finance/csv/iata_data.csv")

# %%
iata_data.head()
# Out:
#   IATI Identifier                                              Title  \
# 0    41120-100879  ROAP/AFG04/22/Secure Communal HLP rights in Af...
# 1    41120-100879  ROAP/AFG04/22/Secure Communal HLP rights in Af...
# 2    41120-102631  ROAP/AFG01/22/Adaptive responses: Evidence bas...
# 3    41120-102631  ROAP/AFG01/22/Adaptive responses: Evidence bas...
# 4    41120-102645  ROAP/AFG05/22/People-friendly Streets in Afgha...
#
#   Reporting Organisation Group Reporting Organisation  \
# 0          UN - United Nations     UN-Habitat [41120]
# 1          UN - United Nations     UN-Habitat [41120]
# 2          UN - United Nations     UN-Habitat [41120]
# 3          UN - United Nations     UN-Habitat [41120]
# 4          UN - United Nations     UN-Habitat [41120]
#
#   Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 0           40 - Multilateral  No data      No data   No data
# 1           40 - Multilateral  No data      No data   No data
# 2           40 - Multilateral  No data      No data   No data
# 3           40 - Multilateral  No data      No data   No data
# 4           40 - Multilateral  No data      No data   No data
#
#   Provider Organisation Provider Organisation Type  ...  \
# 0    UN-Habitat [41120]          40 - Multilateral  ...
# 1       UNOCHA-New York                    No data  ...
# 2    UN-Habitat [41120]          40 - Multilateral  ...
# 3     UNHCR-Afghanistan                    No data  ...
# 4    UN-Habitat [41120]          40 - Multilateral  ...
#
#                                 Sector Category  \
# 0  160 - Other Social Infrastructure & Services
# 1  160 - Other Social Infrastructure & Services
# 2  730 - Reconstruction Relief & Rehabilitation
# 3  730 - Reconstruction Relief & Rehabilitation
# 4                       430 - Other Multisector
#
#                                               Sector Humanitarian  \
# 0  16030 - Housing policy and administrative mana...            0
# 1  16030 - Housing policy and administrative mana...            0
# 2  73010 - Immediate post-emergency reconstructio...            0
# 3  73010 - Immediate post-emergency reconstructio...            0
# 4           43030 - Urban development and management            0
#
#   Calendar Year  Calendar Quarter Calendar Year and Quarter  \
# 0          2025                Q4                   2025 Q4
# 1          2025                Q4                   2025 Q4
# 2          2025                Q4                   2025 Q4
# 3          2025                Q4                   2025 Q4
# 4          2025                Q4                   2025 Q4
#
#                                             URL  Value (USD)    Value (EUR)  \
# 0  https://d-portal.org/q.html?aid=41120-100879    499924.15  432684.914315
# 1  https://d-portal.org/q.html?aid=41120-100879    499940.75  432699.281634
# 2  https://d-portal.org/q.html?aid=41120-102631    314966.64  272603.981305
# 3  https://d-portal.org/q.html?aid=41120-102631    314966.64  272603.981305
# 4  https://d-portal.org/q.html?aid=41120-102645    494995.06  428418.781374
#
#   Value (Local currrency)
# 0            3.882161e+07
# 1            3.882290e+07
# 2            2.445873e+07
# 3            2.445873e+07
# 4            3.843884e+07
#
# [5 rows x 25 columns]

# %%
# create time dimension table

MIN_YEAR = 1970
MAX_YEAR = 2024

years = list(range(MIN_YEAR, MAX_YEAR))
quarters = ["Q1", "Q2", "Q3", "Q4"]

dim_time = pd.DataFrame([(y, q) for y in years for q in quarters],
                        columns=["year", "quarter"])
dim_time["time_id"] = dim_time.index + 1

dim_time.head()
# Out:
#    year quarter  time_id
# 0  1970      Q1        1
# 1  1970      Q2        2
# 2  1970      Q3        3
# 3  1970      Q4        4
# 4  1971      Q1        5

# %%
# filter data by year range listed in dim_time

iata_data_filtered = iata_data[
    (iata_data["Calendar Year"] >= MIN_YEAR) &
    (iata_data["Calendar Year"] <= MAX_YEAR)
].copy()

iata_data_filtered.head()
# Out:
#     IATI Identifier                                              Title  \
# 36  41AAA-11295-001  Procurement and Supply Support of Anti-Tubercu...
# 37  41AAA-11295-014  Diagnostics Procurement Support to Stop Tuberc...
# 38  41AAA-11295-032  Support for the Stop Tuberculosis Partnership ...
# 39  41AAA-11960-007  Support to the Global Environment Facility (GE...
# 40  41AAA-20431-001  Project to Support Improvement of Agricultural...
#
#    Reporting Organisation Group  \
# 36          UN - United Nations
# 37          UN - United Nations
# 38          UN - United Nations
# 39          UN - United Nations
# 40          UN - United Nations
#
#                                Reporting Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 36           40 - Multilateral  No data      No data   No data
# 37           40 - Multilateral  No data      No data   No data
# 38           40 - Multilateral  No data      No data   No data
# 39           40 - Multilateral  No data      No data   No data
# 40           40 - Multilateral  No data      No data   No data
#
#                                 Provider Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Provider Organisation Type  ...                       Sector Category  \
# 36                    No data  ...                          120 - Health
# 37                    No data  ...                          120 - Health
# 38                    No data  ...                          120 - Health
# 39                    No data  ...  410 - General Environment Protection
# 40                    No data  ...  310 - Agriculture, Forestry, Fishing
#
#                                                Sector Humanitarian  \
# 36                       12263 - Tuberculosis control            0
# 37                       12263 - Tuberculosis control            0
# 38                       12263 - Tuberculosis control            0
# 39  41010 - Environmental policy and administrativ...            0
# 40                      31191 - Agricultural services            0
#
#    Calendar Year  Calendar Quarter Calendar Year and Quarter  \
# 36          2016                Q1                   2016 Q1
# 37          2018                Q1                   2018 Q1
# 38          2021                Q2                   2021 Q2
# 39          2015                Q3                   2015 Q3
# 40          2017                Q1                   2017 Q1
#
#                                                 URL  Value (USD)  \
# 36  https://d-portal.org/q.html?aid=41AAA-11295-001    2986309.0
# 37  https://d-portal.org/q.html?aid=41AAA-11295-014    2895425.0
# 38  https://d-portal.org/q.html?aid=41AAA-11295-032     514886.0
# 39  https://d-portal.org/q.html?aid=41AAA-11960-007    1668446.0
# 40  https://d-portal.org/q.html?aid=41AAA-20431-001    9475434.0
#
#      Value (EUR) Value (Local currrency)
# 36  2.743005e+06            2.032183e+08
# 37  2.414262e+06            2.012126e+08
# 38  4.220031e+05            3.998347e+07
# 39  1.491148e+06            1.013080e+08
# 40  8.941619e+06            6.372229e+08
#
# [5 rows x 25 columns]

# %%
# see countries column
countries = iata_data_filtered["Recipient Country or Region"].unique()
country_names = pd.Series(countries)

country_names
# Out:
# 0                                      AF - Afghanistan
# 1                                       BD - Bangladesh
# 2                 BO - Bolivia (Plurinational State of)
# 3                                         CO - Colombia
# 4                                            EG - Egypt
# 5                                         ET - Ethiopia
# 6     GB - United Kingdom of Great Britain and North...
# 7                                          GE - Georgia
# 8                                        GT - Guatemala
# 9                                         HN - Honduras
# 10                                           HT - Haiti
# 11                                       ID - Indonesia
# 12                                          JO - Jordan
# 13                                           KE - Kenya
# 14                                        KH - Cambodia
# 15                                         LB - Lebanon
# 16                       MD - Moldova (the Republic of)
# 17                                      MG - Madagascar
# 18                                         NG - Nigeria
# 19                                       NI - Nicaragua
# 20                                           NP - Nepal
# 21                               PH - Philippines (the)
# 22                                        PK - Pakistan
# 23                                          RW - Rwanda
# 24                                    SL - Sierra Leone
# 25                                         SN - Senegal
# 26                TZ - Tanzania, the United Republic of
# 27                                         UA - Ukraine
# 28                                          UG - Uganda
# 29                  US - United States of America (the)
# 30                                        VN - Viet Nam
# 31                                           YE - Yemen
# dtype: object

# %%
# convert countries to simplier country names
country_map = {
    "AF - Afghanistan": "Afghanistan",
    "BD - Bangladesh": "Bangladesh",
    "BO - Bolivia (Plurinational State of)": "Bolivia",
    "CO - Colombia": "Colombia",
    "EG - Egypt": "Egypt",
    "ET - Ethiopia": "Ethiopia",
    "GB - United Kingdom of Great Britain and Northern Ireland (the)": "United Kingdom",
    "GE - Georgia": "Georgia",
    "GT - Guatemala": "Guatemala",
    "HN - Honduras": "Honduras",
    "HT - Haiti": "Haiti",
    "ID - Indonesia": "Indonesia",
    "JO - Jordan": "Jordan",
    "KE - Kenya": "Kenya",
    "KH - Cambodia": "Cambodia",
    "LB - Lebanon": "Lebanon",
    "MD - Moldova (the Republic of)": "Moldova",
    "MG - Madagascar": "Madagascar",
    "NG - Nigeria": "Nigeria",
    "NI - Nicaragua": "Nicaragua",
    "NP - Nepal": "Nepal",
    "PH - Philippines (the)": "Philippines",
    "PK - Pakistan": "Pakistan",
    "RW - Rwanda": "Rwanda",
    "SL - Sierra Leone": "Sierra Leone",
    "SN - Senegal": "Senegal",
    "TZ - Tanzania, the United Republic of": "Tanzania",
    "UA - Ukraine": "Ukraine",
    "UG - Uganda": "Uganda",
    "US - United States of America (the)": "United States",
    "VN - Viet Nam": "Vietnam",
    "YE - Yemen": "Yemen"
}


# get iso alpha id
iata_data_filtered.loc[:, "country"] = (
    iata_data_filtered["Recipient Country or Region"]
    .map(country_map)
)

# map countries to simpler form
iata_data_filtered.loc[:, "iso_alpha2"] = (
    iata_data_filtered["Recipient Country or Region"]
    .str.split(" - ", expand=True)[0]
)

# %%
iata_data_filtered["iso_alpha2"].unique()
# Out:
# array(['AF', 'BD', 'BO', 'CO', 'EG', 'ET', 'GB', 'GE', 'GT', 'HN', 'HT',
#        'ID', 'JO', 'KE', 'KH', 'LB', 'MD', 'MG', 'NG', 'NI', 'NP', 'PH',
#        'PK', 'RW', 'SL', 'SN', 'TZ', 'UA', 'UG', 'US', 'VN', 'YE'],
#       dtype=object)

# %%
iata_data_filtered["country"].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bolivia', 'Colombia', 'Egypt',
#        'Ethiopia', 'United Kingdom', 'Georgia', 'Guatemala', 'Honduras',
#        'Haiti', 'Indonesia', 'Jordan', 'Kenya', 'Cambodia', 'Lebanon',
#        'Moldova', 'Madagascar', 'Nigeria', 'Nicaragua', 'Nepal',
#        'Philippines', 'Pakistan', 'Rwanda', 'Sierra Leone', 'Senegal',
#        'Tanzania', 'Ukraine', 'Uganda', 'United States', 'Vietnam',
#        'Yemen'], dtype=object)

# %%
# dim_country table
dim_country = (
    iata_data_filtered[["country", "iso_alpha2"]]
        .drop_duplicates()
        .reset_index(drop=True)
)

# add pk
dim_country["country_id"] = dim_country.index + 1


# reorder columns
dim_country = dim_country[["country_id", "country", "iso_alpha2"]]

dim_country.head()
# Out:
#    country_id      country iso_alpha2
# 0           1  Afghanistan         AF
# 1           2   Bangladesh         BD
# 2           3      Bolivia         BO
# 3           4     Colombia         CO
# 4           5        Egypt         EG

# %%
# extract organizations, types, roles via pivot longer
organizations_long = iata_data_filtered.melt(
    id_vars = ["IATI Identifier"],
    value_vars = [
        "Reporting Organisation",
        "Provider Organisation",
        "Receiver Organisation"
    ],
    var_name = "organization_role",
    value_name = "organization_name"
)

organization_types_long = iata_data_filtered.melt(
    id_vars = ["IATI Identifier"],
    value_vars = [
        "Reporting Organisation Type",
        "Provider Organisation Type",
        "Receiver Organisation Type"
    ],
    var_name = "role_type",
    value_name = "organization_type"
)

# %%
organizations_long.head()
# Out:
#   IATI Identifier       organization_role   organization_name
# 0    41120-100879  Reporting Organisation  UN-Habitat [41120]
# 1    41120-100879  Reporting Organisation  UN-Habitat [41120]
# 2    41120-102631  Reporting Organisation  UN-Habitat [41120]
# 3    41120-102631  Reporting Organisation  UN-Habitat [41120]
# 4    41120-102645  Reporting Organisation  UN-Habitat [41120]

# %%
organization_types_long.head()
# Out:
#   IATI Identifier                    role_type  organization_type
# 0    41120-100879  Reporting Organisation Type  40 - Multilateral
# 1    41120-100879  Reporting Organisation Type  40 - Multilateral
# 2    41120-102631  Reporting Organisation Type  40 - Multilateral
# 3    41120-102631  Reporting Organisation Type  40 - Multilateral
# 4    41120-102645  Reporting Organisation Type  40 - Multilateral

# %%
organizations_combined = pd.concat([organizations_long, organization_types_long["organization_type"]], axis=1)
organizations_combined = organizations_combined.dropna(subset=["organization_name"])
organizations_combined["organization_role"] = organizations_combined["organization_role"].str.split().str[0]

organizations_combined.head()
# Out:
#   IATI Identifier organization_role   organization_name  organization_type
# 0    41120-100879         Reporting  UN-Habitat [41120]  40 - Multilateral
# 1    41120-100879         Reporting  UN-Habitat [41120]  40 - Multilateral
# 2    41120-102631         Reporting  UN-Habitat [41120]  40 - Multilateral
# 3    41120-102631         Reporting  UN-Habitat [41120]  40 - Multilateral
# 4    41120-102645         Reporting  UN-Habitat [41120]  40 - Multilateral

# %%
# deduplicate rows

organizations_deduped = (
    organizations_combined[
        ["organization_name", "organization_type"]
    ]
    .drop_duplicates()
    .reset_index(drop=True)
)

organizations_deduped.head()
# Out:
#                                    organization_name  \
# 0                                 UN-Habitat [41120]
# 1  United Nations Office for Project Services (UN...
# 2  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                 Gavi, the vaccine alliance [47122]
# 4     Swedish Committee for Afghanistan [AF-MOE-118]
#
#                  organization_type
# 0                40 - Multilateral
# 1                40 - Multilateral
# 2  30 - Public Private Partnership
# 3                40 - Multilateral
# 4           21 - International NGO

# %%
# extract ids from org name and type, store in seperate columns

organizations_deduped["organization_iati_id"] = (
    organizations_deduped["organization_name"]
    .str.extract(r"\[(.*?)\]")
)

organizations_deduped["organization_name_clean"] = (
    organizations_deduped["organization_name"]
    .str.replace(r"\s*\[\d+\]", "", regex=True)
)

organizations_deduped["organization_type_code"] = (
    organizations_deduped["organization_type"]
    .str.extract(r"^(\d+)")
)

organizations_deduped["organization_type_name"] = (
    organizations_deduped["organization_type"]
    .str.replace(r"^\d+\s*-\s*", "", regex=True)
)

organizations_deduped.head()
# Out:
#                                    organization_name  \
# 0                                 UN-Habitat [41120]
# 1  United Nations Office for Project Services (UN...
# 2  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                 Gavi, the vaccine alliance [47122]
# 4     Swedish Committee for Afghanistan [AF-MOE-118]
#
#                  organization_type organization_iati_id  \
# 0                40 - Multilateral                41120
# 1                40 - Multilateral                41AAA
# 2  30 - Public Private Partnership                47045
# 3                40 - Multilateral                47122
# 4           21 - International NGO           AF-MOE-118
#
#                              organization_name_clean organization_type_code  \
# 0                                         UN-Habitat                     40
# 1  United Nations Office for Project Services (UN...                     40
# 2  The Global Fund to Fight AIDS, Tuberculosis an...                     30
# 3                         Gavi, the vaccine alliance                     40
# 4     Swedish Committee for Afghanistan [AF-MOE-118]                     21
#
#        organization_type_name
# 0                Multilateral
# 1                Multilateral
# 2  Public Private Partnership
# 3                Multilateral
# 4           International NGO

# %%
# build dim organization
dim_organization = organizations_deduped[
    [
        "organization_name_clean",
        "organization_iati_id",
        "organization_type_code",
        "organization_type_name",
        "organization_name"
    ]
].reset_index(drop=True)

dim_organization["organization_id"] = dim_organization.index + 1


# add pk
dim_organization["organization_id"] = dim_organization.index + 1

# rearrange org columns
dim_organization = dim_organization[
    [
        "organization_id",
        "organization_name_clean",
        "organization_iati_id",
        "organization_type_code",
        "organization_type_name",
        "organization_name"
    ]
]

dim_organization.head()
# Out:
#    organization_id                            organization_name_clean  \
# 0                1                                         UN-Habitat
# 1                2  United Nations Office for Project Services (UN...
# 2                3  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                4                         Gavi, the vaccine alliance
# 4                5     Swedish Committee for Afghanistan [AF-MOE-118]
#
#   organization_iati_id organization_type_code      organization_type_name  \
# 0                41120                     40                Multilateral
# 1                41AAA                     40                Multilateral
# 2                47045                     30  Public Private Partnership
# 3                47122                     40                Multilateral
# 4           AF-MOE-118                     21           International NGO
#
#                                    organization_name
# 0                                 UN-Habitat [41120]
# 1  United Nations Office for Project Services (UN...
# 2  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                 Gavi, the vaccine alliance [47122]
# 4     Swedish Committee for Afghanistan [AF-MOE-118]

# %%
dim_organization[dim_organization["organization_name"] == "No data"]
# Out:
#        organization_id organization_name_clean organization_iati_id  \
# 1242              1243                 No data                  NaN
# 1285              1286                 No data                  NaN
# 1387              1388                 No data                  NaN
# 1783              1784                 No data                  NaN
# 1788              1789                 No data                  NaN
# 1820              1821                 No data                  NaN
# 2066              2067                 No data                  NaN
# 2278              2279                 No data                  NaN
# 3794              3795                 No data                  NaN
# 4061              4062                 No data                  NaN
# 6967              6968                 No data                  NaN
# 7116              7117                 No data                  NaN
# 7701              7702                 No data                  NaN
# 12112            12113                 No data                  NaN
# 55364            55365                 No data                  NaN
# 70483            70484                 No data                  NaN
#
#       organization_type_code                   organization_type_name  \
# 1242                     NaN                                  No data
# 1285                      21                        International NGO
# 1387                      90                                    Other
# 1783                      80          Academic, Training and Research
# 1788                      22                             National NGO
# 1820                      10                               Government
# 2066                      40                             Multilateral
# 2278                      71       Private Sector in Provider Country
# 3794                      60                               Foundation
# 4061                      70                           Private Sector
# 6967                      15                      Other Public Sector
# 7116                      11                         Local Government
# 7701                      24                Partner Country based NGO
# 12112                     23                             Regional NGO
# 55364                     72  Private Sector in Aid Recipient Country
# 70483                     30               Public Private Partnership
#
#       organization_name
# 1242            No data
# 1285            No data
# 1387            No data
# 1783            No data
# 1788            No data
# 1820            No data
# 2066            No data
# 2278            No data
# 3794            No data
# 4061            No data
# 6967            No data
# 7116            No data
# 7701            No data
# 12112           No data
# 55364           No data
# 70483           No data

# %%
# get sector fields for dim sector

sector_staging = iata_data_filtered[["Sector Category", "Sector"]].copy()
sector_staging = sector_staging.dropna().drop_duplicates()

sector_staging.head()
# Out:
#                                  Sector Category  \
# 0   160 - Other Social Infrastructure & Services
# 2   730 - Reconstruction Relief & Rehabilitation
# 4                        430 - Other Multisector
# 16                       430 - Other Multisector
# 36                                  120 - Health
#
#                                                Sector
# 0   16030 - Housing policy and administrative mana...
# 2   73010 - Immediate post-emergency reconstructio...
# 4            43030 - Urban development and management
# 16           43082 - Research/scientific institutions
# 36                       12263 - Tuberculosis control

# %%
# split sector category into code + name
sector_staging["sector_category_code"] = (
    sector_staging["Sector Category"].str.extract(r"^(\d+)")
)

sector_staging["sector_category"] = (
    sector_staging["Sector Category"].str.replace(r"^\d+\s*-\s*", "", regex=True)
)

# %%
# split sector into code + name
sector_staging["sector_code"] = (
    sector_staging["Sector"].str.extract(r"^(\d+)")
)

sector_staging["sector_name"] = (
    sector_staging["Sector"].str.replace(r"^\d+\s*-\s*", "", regex=True)
)

sector_staging.head()
# Out:
#                                  Sector Category  \
# 0   160 - Other Social Infrastructure & Services
# 2   730 - Reconstruction Relief & Rehabilitation
# 4                        430 - Other Multisector
# 16                       430 - Other Multisector
# 36                                  120 - Health
#
#                                                Sector sector_category_code  \
# 0   16030 - Housing policy and administrative mana...                  160
# 2   73010 - Immediate post-emergency reconstructio...                  730
# 4            43030 - Urban development and management                  430
# 16           43082 - Research/scientific institutions                  430
# 36                       12263 - Tuberculosis control                  120
#
#                            sector_category sector_code  \
# 0   Other Social Infrastructure & Services       16030
# 2   Reconstruction Relief & Rehabilitation       73010
# 4                        Other Multisector       43030
# 16                       Other Multisector       43082
# 36                                  Health       12263
#
#                                           sector_name
# 0        Housing policy and administrative management
# 2   Immediate post-emergency reconstruction and re...
# 4                    Urban development and management
# 16                   Research/scientific institutions
# 36                               Tuberculosis control

# %%
# set up sector dimension

dim_sector = sector_staging[
    [
        "sector_code",
        "sector_name",
        "sector_category_code",
        "sector_category"
    ]
].drop_duplicates().reset_index(drop=True)

# add primary key
dim_sector["sector_id"] = dim_sector.index + 1

# reorder cols
dim_sector = dim_sector[
    [
        "sector_id",
        "sector_code",
        "sector_name",
        "sector_category_code",
        "sector_category"
    ]
]

dim_sector.head()
# Out:
#    sector_id sector_code                                        sector_name  \
# 0          1       16030       Housing policy and administrative management
# 1          2       73010  Immediate post-emergency reconstruction and re...
# 2          3       43030                   Urban development and management
# 3          4       43082                   Research/scientific institutions
# 4          5       12263                               Tuberculosis control
#
#   sector_category_code                         sector_category
# 0                  160  Other Social Infrastructure & Services
# 1                  730  Reconstruction Relief & Rehabilitation
# 2                  430                       Other Multisector
# 3                  430                       Other Multisector
# 4                  120                                  Health

# %%
aid_staging = iata_data_filtered[["Aid Type"]].dropna().drop_duplicates()
aid_staging.head()
# Out:
#                                                Aid Type
# 0                                               No data
# 69                     C01 - Project-type interventions
# 1181  B03 - Contributions to specific-purpose progra...
# 1775       E01 - Scholarships/training in donor country
# 1956                  B04 - Basket funds/pooled funding

# %%
# split aid type into code and name


aid_staging["aid_type_code"] = aid_staging["Aid Type"].str.extract(r"^(\S+)")
aid_staging["aid_type_name"] = aid_staging["Aid Type"].str.replace(r"^\S+\s*-\s*", "", regex=True)


# set type code to none for int
aid_staging["aid_type_code"] = aid_staging["aid_type_code"].replace("No", None)
aid_staging.head()
# Out:
#                                                Aid Type aid_type_code  \
# 0                                               No data          None
# 69                     C01 - Project-type interventions           C01
# 1181  B03 - Contributions to specific-purpose progra...           B03
# 1775       E01 - Scholarships/training in donor country           E01
# 1956                  B04 - Basket funds/pooled funding           B04
#
#                                           aid_type_name
# 0                                               No data
# 69                           Project-type interventions
# 1181  Contributions to specific-purpose programmes a...
# 1775             Scholarships/training in donor country
# 1956                        Basket funds/pooled funding

# %%
# build aid dimension

dim_aid_type = (
    aid_staging[["aid_type_code", "aid_type_name"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

# add pk
dim_aid_type["aid_type_id"] = dim_aid_type.index + 1

dim_aid_type = dim_aid_type[
    ["aid_type_id", "aid_type_code", "aid_type_name"]
]

dim_aid_type.head()
# Out:
#    aid_type_id aid_type_code  \
# 0            1          None
# 1            2           C01
# 2            3           B03
# 3            4           E01
# 4            5           B04
#
#                                        aid_type_name
# 0                                            No data
# 1                         Project-type interventions
# 2  Contributions to specific-purpose programmes a...
# 3             Scholarships/training in donor country
# 4                        Basket funds/pooled funding

# %%
# flow type staging
flow_staging = iata_data_filtered[["Flow Type"]].copy()
flow_staging = flow_staging.drop_duplicates()


flow_staging.head()
# Out:
#                              Flow Type
# 0                              No data
# 69                            10 - ODA
# 2531        21 - Non-export credit OOF
# 4421  30 - Private Development Finance
# 4427                  50 - Other flows

# %%
# split flow type into code and name
flow_staging["flow_type_code"] = flow_staging["Flow Type"].str.extract(r"^(\S+)")

flow_staging["flow_type_name"] = flow_staging["Flow Type"].str.replace(
    r"^\S+\s*-\s*", "", regex=True
)

# set type code to none as well to support int
flow_staging["flow_type_code"] = flow_staging["flow_type_code"].replace("No", None)

flow_staging.head()
# Out:
#                              Flow Type flow_type_code  \
# 0                              No data           None
# 69                            10 - ODA             10
# 2531        21 - Non-export credit OOF             21
# 4421  30 - Private Development Finance             30
# 4427                  50 - Other flows             50
#
#                    flow_type_name
# 0                         No data
# 69                            ODA
# 2531        Non-export credit OOF
# 4421  Private Development Finance
# 4427                  Other flows

# %%
# build flow dimension

dim_flow_type = (
    flow_staging[["flow_type_code", "flow_type_name"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

# add pk
dim_flow_type["flow_type_id"] = dim_flow_type.index + 1

dim_flow_type = dim_flow_type[
    ["flow_type_id", "flow_type_code", "flow_type_name"]
]


dim_flow_type.head()
# Out:
#    flow_type_id flow_type_code               flow_type_name
# 0             1           None                      No data
# 1             2             10                          ODA
# 2             3             21        Non-export credit OOF
# 3             4             30  Private Development Finance
# 4             5             50                  Other flows

# %%
transaction_staging = iata_data_filtered[["Transaction Type"]].copy()
transaction_staging = transaction_staging.drop_duplicates()


transaction_staging.head()
# Out:
#               Transaction Type
# 0              4 - Expenditure
# 1           1 - Incoming Funds
# 69     2 - Outgoing Commitment
# 72            3 - Disbursement
# 73955          budget - Budget

# %%
transaction_staging["transaction_type_code"] = transaction_staging["Transaction Type"].str.extract(r"^(\S+)")
transaction_staging["transaction_type_name"] = transaction_staging["Transaction Type"].str.replace(r"^\S+\s*-\s*", "", regex=True)


transaction_staging.head()
# Out:
#               Transaction Type transaction_type_code transaction_type_name
# 0              4 - Expenditure                     4           Expenditure
# 1           1 - Incoming Funds                     1        Incoming Funds
# 69     2 - Outgoing Commitment                     2   Outgoing Commitment
# 72            3 - Disbursement                     3          Disbursement
# 73955          budget - Budget                budget                Budget

# %%
# build transaction dimension
dim_transaction_type = (
    transaction_staging[["transaction_type_code", "transaction_type_name"]]
    .drop_duplicates()
    .reset_index(drop=True)
)
# pk
dim_transaction_type["transaction_type_id"] = dim_transaction_type.index + 1

# reorder cols
dim_transaction_type = dim_transaction_type[
    ["transaction_type_id", "transaction_type_code", "transaction_type_name"]
]

dim_transaction_type.head()
# Out:
#    transaction_type_id transaction_type_code transaction_type_name
# 0                    1                     4           Expenditure
# 1                    2                     1        Incoming Funds
# 2                    3                     2   Outgoing Commitment
# 3                    4                     3          Disbursement
# 4                    5                budget                Budget

# %%
# finance type staging

finance_staging = iata_data_filtered[["Finance Type"]].copy()
finance_staging = finance_staging.drop_duplicates()

finance_staging.head()
# Out:
#                                             Finance Type
# 0                                                No data
# 69                                  110 - Standard grant
# 6078      311 - Capital subscription on encashment basis
# 8969                                 421 - Standard loan
# 12165  511 - Acquisition of equity not part of joint ...

# %%
# extract code and name from finance type

finance_staging["finance_type_code"] = finance_staging["Finance Type"].str.extract(r"^(\S+)")
finance_staging["finance_type_name"] = finance_staging["Finance Type"].str.replace(r"^\S+\s*-\s*", "", regex=True)

# set type code to no data as well for better null consistency
finance_staging["finance_type_code"] = finance_staging["finance_type_code"].replace("No", None)


finance_staging.head()
# Out:
#                                             Finance Type finance_type_code  \
# 0                                                No data              None
# 69                                  110 - Standard grant               110
# 6078      311 - Capital subscription on encashment basis               311
# 8969                                 421 - Standard loan               421
# 12165  511 - Acquisition of equity not part of joint ...               511
#
#                                        finance_type_name
# 0                                                No data
# 69                                        Standard grant
# 6078            Capital subscription on encashment basis
# 8969                                       Standard loan
# 12165  Acquisition of equity not part of joint ventur...

# %%
# build finance dimension

dim_finance_type = (
    finance_staging[["finance_type_code", "finance_type_name"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

dim_finance_type["finance_type_id"] = dim_finance_type.index + 1


dim_finance_type = dim_finance_type[
    ["finance_type_id", "finance_type_code", "finance_type_name"]
]

dim_finance_type.head()
# Out:
#    finance_type_id finance_type_code  \
# 0                1              None
# 1                2               110
# 2                3               311
# 3                4               421
# 4                5               511
#
#                                    finance_type_name
# 0                                            No data
# 1                                     Standard grant
# 2           Capital subscription on encashment basis
# 3                                      Standard loan
# 4  Acquisition of equity not part of joint ventur...

# %%
world_indicator_data = pd.read_csv("data/world-development-indicators/data2.csv")

world_indicator_data.head()
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1  Population density (people per sq. km of land ...     EN.POP.DNST
# 2                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 4    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT
#
#       1970 [YR1970]     1971 [YR1971]     1972 [YR1972]     1973 [YR1973]  \
# 0         205052000         207661000         209896000         211909000
# 1  22.3881314035655  22.6729890729952  22.9170124118896  23.1367971909474
# 2   5234.2966662115  5609.38259952519  6094.01798986165  6726.35895596695
# 3  70.8073170731707  71.1073170731707  71.1560975609756  71.3560975609756
# 4              23.2              22.4              21.5              20.6
#
#       1974 [YR1974]     1975 [YR1975]  ...     2014 [YR2014]  \
# 0         213854000         215973000  ...         319257560
# 1  23.3491575462716  23.5805156917379  ...  34.9013776562134
# 2  7225.69135952566  7801.45666356443  ...  54973.4207515712
# 3  71.9560975609756  72.6048780487805  ...  78.8414634146341
# 4              19.7              18.8  ...               6.8
#
#       2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 0         321815121         324353340         326608609         328529577
# 1  35.1809713558577  35.4584505795077  35.7049975840182  35.9149986553586
# 2  56572.9188996063  57638.1018367192  59635.0984397965  62499.8744390068
# 3   78.690243902439  78.5390243902439  78.5390243902439  78.6390243902439
# 4               6.8               6.7               6.6               6.5
#
#       2019 [YR2019]     2020 [YR2020]     2021 [YR2021]     2022 [YR2022]  \
# 0         330226227         331577720         332099760         334017321
# 1  36.1004771837305   36.248222996211  36.3052926398919  36.5149212564854
# 2  64746.4506778863  63515.9491807833   70205.050916026  76657.2488844403
# 3  78.7878048780488  76.9804878048781  76.3292682926829  77.4341463414634
# 4               6.5               6.5               6.5               6.5
#
#       2023 [YR2023]
# 0         336806231
# 1  36.8198061311277
# 2   81032.262117545
# 3  78.3853658536585
# 4               6.5
#
# [5 rows x 58 columns]

# %%
# long pivot the years

indicator_long = world_indicator_data.melt(
    id_vars=["Country Name", "Country Code", "Series Name", "Series Code"],
    var_name="year",
    value_name="value"
)

indicator_long.head()
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1  Population density (people per sq. km of land ...     EN.POP.DNST
# 2                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 4    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT
#
#             year             value
# 0  1970 [YR1970]         205052000
# 1  1970 [YR1970]  22.3881314035655
# 2  1970 [YR1970]   5234.2966662115
# 3  1970 [YR1970]  70.8073170731707
# 4  1970 [YR1970]              23.2

# %%
# year has weird values so convert

indicator_long["year"] = indicator_long["year"].str.extract(r"(\d{4})").astype(int)

indicator_long.head(1)
# Out:
#     Country Name Country Code        Series Name  Series Code  year      value
# 0  United States          USA  Population, total  SP.POP.TOTL  1970  205052000

# %%
# look at distinct series

indicator_long["Series Name"].unique()
# Out:
# array(['Population, total',
#        'Population density (people per sq. km of land area)',
#        'GDP per capita (current US$)',
#        'Life expectancy at birth, total (years)',
#        'Mortality rate, under-5 (per 1,000 live births)',
#        'Primary completion rate, total (% of relevant age group)',
#        'School enrollment, primary (% net)',
#        'Lower secondary completion rate, total (% of relevant age group)',
#        'Net ODA received per capita (current US$)', nan], dtype=object)

# %%
# make a map to convert the names to readable format

indicator_map = {
    "Population, total": "population",
    "Population density (people per sq. km of land area)": "population_density",
    "GDP per capita (current US$)": "gdp_per_capita",
    "Net ODA received per capita (current US$)": "net_oda_per_capita",
    "Life expectancy at birth, total (years)": "life_expectancy",
    "Mortality rate, under-5 (per 1,000 live births)": "under5_mortality",
    "Primary completion rate, total (% of relevant age group)": "primary_completion_rate",
    "Lower secondary completion rate, total (% of relevant age group)": "lower_secondary_completion_rate",
    "School enrollment, primary (% net)": "school_enrollment_primary"
}


indicator_long["metric"] = indicator_long["Series Name"].map(indicator_map)

indicator_long.head()
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
#
#                                          Series Name     Series Code  year  \
# 0                                  Population, total     SP.POP.TOTL  1970
# 1  Population density (people per sq. km of land ...     EN.POP.DNST  1970
# 2                       GDP per capita (current US$)  NY.GDP.PCAP.CD  1970
# 3            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1970
# 4    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT  1970
#
#               value              metric
# 0         205052000          population
# 1  22.3881314035655  population_density
# 2   5234.2966662115      gdp_per_capita
# 3  70.8073170731707     life_expectancy
# 4              23.2    under5_mortality

# %%
# theres weird rows where theres no data at all so filter it out (verified using R)

indicator_long = indicator_long[indicator_long["metric"].notna()].copy()
indicator_long = indicator_long[indicator_long["year"] < 2024].copy()

# theres "..." entries as opposed to n/a entries
indicator_long["value"] = indicator_long["value"].replace("..", None)

# convert numeric
indicator_long["value"] = pd.to_numeric(indicator_long["value"], errors="coerce")

# %%
# pivot again to convert metrics to seperate columns

indicator_pivoted = indicator_long.pivot_table(
    index=["Country Name", "Country Code", "year"],
    columns="metric",
    values="value"
).reset_index()

indicator_pivoted.head()
# Out:
# metric Country Name Country Code  year  gdp_per_capita  life_expectancy  \
# 0       Afghanistan          AFG  1970             NaN           37.460
# 1       Afghanistan          AFG  1971             NaN           37.932
# 2       Afghanistan          AFG  1972             NaN           38.423
# 3       Afghanistan          AFG  1973             NaN           38.951
# 4       Afghanistan          AFG  1974             NaN           39.469
#
# metric  lower_secondary_completion_rate  net_oda_per_capita  population  \
# 0                                   NaN            2.445499  11290128.0
# 1                                   NaN            3.841743  11567667.0
# 2                                   NaN            4.655088  11853696.0
# 3                               9.78837            4.582991  12157999.0
# 4                               8.57250            3.922488  12469127.0
#
# metric  population_density  primary_completion_rate  \
# 0                17.310041                      NaN
# 1                17.735564                      NaN
# 2                18.174104                      NaN
# 3                18.640662                      NaN
# 4                19.117684                17.058519
#
# metric  school_enrollment_primary  under5_mortality
# 0                             NaN             301.6
# 1                             NaN             296.5
# 2                             NaN             291.4
# 3                             NaN             285.9
# 4                        26.82221             280.6

# %%
# verify country names
indicator_pivoted["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bolivia', 'Cambodia', 'Colombia',
#        'Egypt, Arab Rep.', 'Ethiopia', 'Georgia', 'Guatemala', 'Haiti',
#        'Honduras', 'Indonesia', 'Jordan', 'Kenya', 'Lebanon',
#        'Madagascar', 'Moldova', 'Nepal', 'Nicaragua', 'Nigeria',
#        'Pakistan', 'Philippines', 'Rwanda', 'Senegal', 'Sierra Leone',
#        'Tanzania', 'Uganda', 'Ukraine', 'United Kingdom', 'United States',
#        'Viet Nam', 'Yemen, Rep.'], dtype=object)

# %%
# map country names to

country_mapping = {
    "Afghanistan": "Afghanistan",
    "Bangladesh": "Bangladesh",
    "Bolivia": "Bolivia",
    "Cambodia": "Cambodia",
    "Colombia": "Colombia",
    "Egypt, Arab Rep.": "Egypt",
    "Ethiopia": "Ethiopia",
    "Georgia": "Georgia",
    "Guatemala": "Guatemala",
    "Haiti": "Haiti",
    "Honduras": "Honduras",
    "Indonesia": "Indonesia",
    "Jordan": "Jordan",
    "Kenya": "Kenya",
    "Lebanon": "Lebanon",
    "Madagascar": "Madagascar",
    "Moldova": "Moldova",
    "Nepal": "Nepal",
    "Nicaragua": "Nicaragua",
    "Nigeria": "Nigeria",
    "Pakistan": "Pakistan",
    "Philippines": "Philippines",
    "Rwanda": "Rwanda",
    "Senegal": "Senegal",
    "Sierra Leone": "Sierra Leone",
    "Tanzania": "Tanzania",
    "Uganda": "Uganda",
    "Ukraine": "Ukraine",
    "United Kingdom": "United Kingdom",
    "United States": "United States",
    "Viet Nam": "Vietnam",
    "Yemen, Rep.": "Yemen"
}

indicator_pivoted["country_clean"] = indicator_pivoted["Country Name"].map(country_mapping)

indicator_pivoted.head()
# Out:
# metric Country Name Country Code  year  gdp_per_capita  life_expectancy  \
# 0       Afghanistan          AFG  1970             NaN           37.460
# 1       Afghanistan          AFG  1971             NaN           37.932
# 2       Afghanistan          AFG  1972             NaN           38.423
# 3       Afghanistan          AFG  1973             NaN           38.951
# 4       Afghanistan          AFG  1974             NaN           39.469
#
# metric  lower_secondary_completion_rate  net_oda_per_capita  population  \
# 0                                   NaN            2.445499  11290128.0
# 1                                   NaN            3.841743  11567667.0
# 2                                   NaN            4.655088  11853696.0
# 3                               9.78837            4.582991  12157999.0
# 4                               8.57250            3.922488  12469127.0
#
# metric  population_density  primary_completion_rate  \
# 0                17.310041                      NaN
# 1                17.735564                      NaN
# 2                18.174104                      NaN
# 3                18.640662                      NaN
# 4                19.117684                17.058519
#
# metric  school_enrollment_primary  under5_mortality country_clean
# 0                             NaN             301.6   Afghanistan
# 1                             NaN             296.5   Afghanistan
# 2                             NaN             291.4   Afghanistan
# 3                             NaN             285.9   Afghanistan
# 4                        26.82221             280.6   Afghanistan

# %%
indicator_pivoted["country_clean"].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bolivia', 'Cambodia', 'Colombia',
#        'Egypt', 'Ethiopia', 'Georgia', 'Guatemala', 'Haiti', 'Honduras',
#        'Indonesia', 'Jordan', 'Kenya', 'Lebanon', 'Madagascar', 'Moldova',
#        'Nepal', 'Nicaragua', 'Nigeria', 'Pakistan', 'Philippines',
#        'Rwanda', 'Senegal', 'Sierra Leone', 'Tanzania', 'Uganda',
#        'Ukraine', 'United Kingdom', 'United States', 'Vietnam', 'Yemen'],
#       dtype=object)

# %%
# add quarter for joining
indicator_pivoted["quarter"] = "Q1"

# %%
fact_indicator = indicator_pivoted.merge(
    dim_country[["country_id", "country"]],
    left_on="country_clean",
    right_on="country",
    how="left"
)

fact_indicator.head()
# Out:
#   Country Name Country Code  year  gdp_per_capita  life_expectancy  \
# 0  Afghanistan          AFG  1970             NaN           37.460
# 1  Afghanistan          AFG  1971             NaN           37.932
# 2  Afghanistan          AFG  1972             NaN           38.423
# 3  Afghanistan          AFG  1973             NaN           38.951
# 4  Afghanistan          AFG  1974             NaN           39.469
#
#    lower_secondary_completion_rate  net_oda_per_capita  population  \
# 0                              NaN            2.445499  11290128.0
# 1                              NaN            3.841743  11567667.0
# 2                              NaN            4.655088  11853696.0
# 3                          9.78837            4.582991  12157999.0
# 4                          8.57250            3.922488  12469127.0
#
#    population_density  primary_completion_rate  school_enrollment_primary  \
# 0           17.310041                      NaN                        NaN
# 1           17.735564                      NaN                        NaN
# 2           18.174104                      NaN                        NaN
# 3           18.640662                      NaN                        NaN
# 4           19.117684                17.058519                   26.82221
#
#    under5_mortality country_clean quarter  country_id      country
# 0             301.6   Afghanistan      Q1           1  Afghanistan
# 1             296.5   Afghanistan      Q1           1  Afghanistan
# 2             291.4   Afghanistan      Q1           1  Afghanistan
# 3             285.9   Afghanistan      Q1           1  Afghanistan
# 4             280.6   Afghanistan      Q1           1  Afghanistan

# %%
fact_indicator = fact_indicator.merge(
    dim_time,
    on=["year", "quarter"],
    how="left"
)
fact_indicator.head()
# Out:
#   Country Name Country Code  year  gdp_per_capita  life_expectancy  \
# 0  Afghanistan          AFG  1970             NaN           37.460
# 1  Afghanistan          AFG  1971             NaN           37.932
# 2  Afghanistan          AFG  1972             NaN           38.423
# 3  Afghanistan          AFG  1973             NaN           38.951
# 4  Afghanistan          AFG  1974             NaN           39.469
#
#    lower_secondary_completion_rate  net_oda_per_capita  population  \
# 0                              NaN            2.445499  11290128.0
# 1                              NaN            3.841743  11567667.0
# 2                              NaN            4.655088  11853696.0
# 3                          9.78837            4.582991  12157999.0
# 4                          8.57250            3.922488  12469127.0
#
#    population_density  primary_completion_rate  school_enrollment_primary  \
# 0           17.310041                      NaN                        NaN
# 1           17.735564                      NaN                        NaN
# 2           18.174104                      NaN                        NaN
# 3           18.640662                      NaN                        NaN
# 4           19.117684                17.058519                   26.82221
#
#    under5_mortality country_clean quarter  country_id      country  time_id
# 0             301.6   Afghanistan      Q1           1  Afghanistan        1
# 1             296.5   Afghanistan      Q1           1  Afghanistan        5
# 2             291.4   Afghanistan      Q1           1  Afghanistan        9
# 3             285.9   Afghanistan      Q1           1  Afghanistan       13
# 4             280.6   Afghanistan      Q1           1  Afghanistan       17

# %%
# clean table, drop unnecessary colss and reorder
fact_indicator = fact_indicator[
    [
        "country_id",
        "time_id",
        "population",
        "population_density",
        "gdp_per_capita",
        "net_oda_per_capita",
        "life_expectancy",
        "under5_mortality",
        "primary_completion_rate",
        "lower_secondary_completion_rate",
        "school_enrollment_primary"
    ]
]

fact_indicator.head()
# Out:
#    country_id  time_id  population  population_density  gdp_per_capita  \
# 0           1        1  11290128.0           17.310041             NaN
# 1           1        5  11567667.0           17.735564             NaN
# 2           1        9  11853696.0           18.174104             NaN
# 3           1       13  12157999.0           18.640662             NaN
# 4           1       17  12469127.0           19.117684             NaN
#
#    net_oda_per_capita  life_expectancy  under5_mortality  \
# 0            2.445499           37.460             301.6
# 1            3.841743           37.932             296.5
# 2            4.655088           38.423             291.4
# 3            4.582991           38.951             285.9
# 4            3.922488           39.469             280.6
#
#    primary_completion_rate  lower_secondary_completion_rate  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                          9.78837
# 4                17.058519                          8.57250
#
#    school_enrollment_primary
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                   26.82221

# %%
# check columns
iata_data_filtered.head()
# Out:
#     IATI Identifier                                              Title  \
# 36  41AAA-11295-001  Procurement and Supply Support of Anti-Tubercu...
# 37  41AAA-11295-014  Diagnostics Procurement Support to Stop Tuberc...
# 38  41AAA-11295-032  Support for the Stop Tuberculosis Partnership ...
# 39  41AAA-11960-007  Support to the Global Environment Facility (GE...
# 40  41AAA-20431-001  Project to Support Improvement of Agricultural...
#
#    Reporting Organisation Group  \
# 36          UN - United Nations
# 37          UN - United Nations
# 38          UN - United Nations
# 39          UN - United Nations
# 40          UN - United Nations
#
#                                Reporting Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 36           40 - Multilateral  No data      No data   No data
# 37           40 - Multilateral  No data      No data   No data
# 38           40 - Multilateral  No data      No data   No data
# 39           40 - Multilateral  No data      No data   No data
# 40           40 - Multilateral  No data      No data   No data
#
#                                 Provider Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Provider Organisation Type  ... Humanitarian Calendar Year  \
# 36                    No data  ...            0          2016
# 37                    No data  ...            0          2018
# 38                    No data  ...            0          2021
# 39                    No data  ...            0          2015
# 40                    No data  ...            0          2017
#
#    Calendar Quarter Calendar Year and Quarter  \
# 36               Q1                   2016 Q1
# 37               Q1                   2018 Q1
# 38               Q2                   2021 Q2
# 39               Q3                   2015 Q3
# 40               Q1                   2017 Q1
#
#                                                 URL Value (USD)   Value (EUR)  \
# 36  https://d-portal.org/q.html?aid=41AAA-11295-001   2986309.0  2.743005e+06
# 37  https://d-portal.org/q.html?aid=41AAA-11295-014   2895425.0  2.414262e+06
# 38  https://d-portal.org/q.html?aid=41AAA-11295-032    514886.0  4.220031e+05
# 39  https://d-portal.org/q.html?aid=41AAA-11960-007   1668446.0  1.491148e+06
# 40  https://d-portal.org/q.html?aid=41AAA-20431-001   9475434.0  8.941619e+06
#
#     Value (Local currrency)      country iso_alpha2
# 36             2.032183e+08  Afghanistan         AF
# 37             2.012126e+08  Afghanistan         AF
# 38             3.998347e+07  Afghanistan         AF
# 39             1.013080e+08  Afghanistan         AF
# 40             6.372229e+08  Afghanistan         AF
#
# [5 rows x 27 columns]

# %%
fact_iata = iata_data_filtered.rename(columns={
    "IATI Identifier": "iati_id",
    "Title": "aid_title",
    "Value (USD)": "value_usd",
    "Value (EUR)": "value_euro",
    "Value (Local currrency)": "value_local",
    "Humanitarian": "humanitarian",
    "Calendar Year": "year",
    "Calendar Quarter": "quarter",
})

fact_iata.head()
# Out:
#             iati_id                                          aid_title  \
# 36  41AAA-11295-001  Procurement and Supply Support of Anti-Tubercu...
# 37  41AAA-11295-014  Diagnostics Procurement Support to Stop Tuberc...
# 38  41AAA-11295-032  Support for the Stop Tuberculosis Partnership ...
# 39  41AAA-11960-007  Support to the Global Environment Facility (GE...
# 40  41AAA-20431-001  Project to Support Improvement of Agricultural...
#
#    Reporting Organisation Group  \
# 36          UN - United Nations
# 37          UN - United Nations
# 38          UN - United Nations
# 39          UN - United Nations
# 40          UN - United Nations
#
#                                Reporting Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 36           40 - Multilateral  No data      No data   No data
# 37           40 - Multilateral  No data      No data   No data
# 38           40 - Multilateral  No data      No data   No data
# 39           40 - Multilateral  No data      No data   No data
# 40           40 - Multilateral  No data      No data   No data
#
#                                 Provider Organisation  \
# 36  United Nations Office for Project Services (UN...
# 37  United Nations Office for Project Services (UN...
# 38  United Nations Office for Project Services (UN...
# 39  United Nations Office for Project Services (UN...
# 40  United Nations Office for Project Services (UN...
#
#    Provider Organisation Type  ... humanitarian  year quarter  \
# 36                    No data  ...            0  2016      Q1
# 37                    No data  ...            0  2018      Q1
# 38                    No data  ...            0  2021      Q2
# 39                    No data  ...            0  2015      Q3
# 40                    No data  ...            0  2017      Q1
#
#    Calendar Year and Quarter                                              URL  \
# 36                   2016 Q1  https://d-portal.org/q.html?aid=41AAA-11295-001
# 37                   2018 Q1  https://d-portal.org/q.html?aid=41AAA-11295-014
# 38                   2021 Q2  https://d-portal.org/q.html?aid=41AAA-11295-032
# 39                   2015 Q3  https://d-portal.org/q.html?aid=41AAA-11960-007
# 40                   2017 Q1  https://d-portal.org/q.html?aid=41AAA-20431-001
#
#     value_usd    value_euro   value_local      country iso_alpha2
# 36  2986309.0  2.743005e+06  2.032183e+08  Afghanistan         AF
# 37  2895425.0  2.414262e+06  2.012126e+08  Afghanistan         AF
# 38   514886.0  4.220031e+05  3.998347e+07  Afghanistan         AF
# 39  1668446.0  1.491148e+06  1.013080e+08  Afghanistan         AF
# 40  9475434.0  8.941619e+06  6.372229e+08  Afghanistan         AF
#
# [5 rows x 27 columns]

# %%
# add country id to fact table by merging
fact_iata = fact_iata.merge(
    dim_country[["country_id", "country"]],
    on="country",
    how="left"
)

# %%
fact_iata.head()
# Out:
#            iati_id                                          aid_title  \
# 0  41AAA-11295-001  Procurement and Supply Support of Anti-Tubercu...
# 1  41AAA-11295-014  Diagnostics Procurement Support to Stop Tuberc...
# 2  41AAA-11295-032  Support for the Stop Tuberculosis Partnership ...
# 3  41AAA-11960-007  Support to the Global Environment Facility (GE...
# 4  41AAA-20431-001  Project to Support Improvement of Agricultural...
#
#   Reporting Organisation Group  \
# 0          UN - United Nations
# 1          UN - United Nations
# 2          UN - United Nations
# 3          UN - United Nations
# 4          UN - United Nations
#
#                               Reporting Organisation  \
# 0  United Nations Office for Project Services (UN...
# 1  United Nations Office for Project Services (UN...
# 2  United Nations Office for Project Services (UN...
# 3  United Nations Office for Project Services (UN...
# 4  United Nations Office for Project Services (UN...
#
#   Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 0           40 - Multilateral  No data      No data   No data
# 1           40 - Multilateral  No data      No data   No data
# 2           40 - Multilateral  No data      No data   No data
# 3           40 - Multilateral  No data      No data   No data
# 4           40 - Multilateral  No data      No data   No data
#
#                                Provider Organisation  \
# 0  United Nations Office for Project Services (UN...
# 1  United Nations Office for Project Services (UN...
# 2  United Nations Office for Project Services (UN...
# 3  United Nations Office for Project Services (UN...
# 4  United Nations Office for Project Services (UN...
#
#   Provider Organisation Type  ...  year quarter Calendar Year and Quarter  \
# 0                    No data  ...  2016      Q1                   2016 Q1
# 1                    No data  ...  2018      Q1                   2018 Q1
# 2                    No data  ...  2021      Q2                   2021 Q2
# 3                    No data  ...  2015      Q3                   2015 Q3
# 4                    No data  ...  2017      Q1                   2017 Q1
#
#                                                URL  value_usd    value_euro  \
# 0  https://d-portal.org/q.html?aid=41AAA-11295-001  2986309.0  2.743005e+06
# 1  https://d-portal.org/q.html?aid=41AAA-11295-014  2895425.0  2.414262e+06
# 2  https://d-portal.org/q.html?aid=41AAA-11295-032   514886.0  4.220031e+05
# 3  https://d-portal.org/q.html?aid=41AAA-11960-007  1668446.0  1.491148e+06
# 4  https://d-portal.org/q.html?aid=41AAA-20431-001  9475434.0  8.941619e+06
#
#     value_local      country  iso_alpha2 country_id
# 0  2.032183e+08  Afghanistan          AF          1
# 1  2.012126e+08  Afghanistan          AF          1
# 2  3.998347e+07  Afghanistan          AF          1
# 3  1.013080e+08  Afghanistan          AF          1
# 4  6.372229e+08  Afghanistan          AF          1
#
# [5 rows x 28 columns]

# %%
# add time id to fact table by merging
fact_iata = fact_iata.merge(
    dim_time,
    left_on=["year", "quarter"],
    right_on=["year", "quarter"],
    how="left"
)

# %%
fact_iata = fact_iata.merge(
    dim_organization[[
        "organization_id",
        "organization_name",
        "organization_type_name"
    ]],
    left_on=["Reporting Organisation", "Reporting Organisation Type"],
    right_on=["organization_name", "organization_type_name"],
    how="left"
).rename(columns={"organization_id": "reporting_org_id"})

fact_iata = fact_iata.drop(columns=["organization_name", "organization_type_name"])

# %%
fact_iata.head()
# Out:
#            iati_id                                          aid_title  \
# 0  41AAA-11295-001  Procurement and Supply Support of Anti-Tubercu...
# 1  41AAA-11295-014  Diagnostics Procurement Support to Stop Tuberc...
# 2  41AAA-11295-032  Support for the Stop Tuberculosis Partnership ...
# 3  41AAA-11960-007  Support to the Global Environment Facility (GE...
# 4  41AAA-20431-001  Project to Support Improvement of Agricultural...
#
#   Reporting Organisation Group  \
# 0          UN - United Nations
# 1          UN - United Nations
# 2          UN - United Nations
# 3          UN - United Nations
# 4          UN - United Nations
#
#                               Reporting Organisation  \
# 0  United Nations Office for Project Services (UN...
# 1  United Nations Office for Project Services (UN...
# 2  United Nations Office for Project Services (UN...
# 3  United Nations Office for Project Services (UN...
# 4  United Nations Office for Project Services (UN...
#
#   Reporting Organisation Type Aid Type Finance Type Flow Type  \
# 0           40 - Multilateral  No data      No data   No data
# 1           40 - Multilateral  No data      No data   No data
# 2           40 - Multilateral  No data      No data   No data
# 3           40 - Multilateral  No data      No data   No data
# 4           40 - Multilateral  No data      No data   No data
#
#                                Provider Organisation  \
# 0  United Nations Office for Project Services (UN...
# 1  United Nations Office for Project Services (UN...
# 2  United Nations Office for Project Services (UN...
# 3  United Nations Office for Project Services (UN...
# 4  United Nations Office for Project Services (UN...
#
#   Provider Organisation Type  ... Calendar Year and Quarter  \
# 0                    No data  ...                   2016 Q1
# 1                    No data  ...                   2018 Q1
# 2                    No data  ...                   2021 Q2
# 3                    No data  ...                   2015 Q3
# 4                    No data  ...                   2017 Q1
#
#                                                URL  value_usd    value_euro  \
# 0  https://d-portal.org/q.html?aid=41AAA-11295-001  2986309.0  2.743005e+06
# 1  https://d-portal.org/q.html?aid=41AAA-11295-014  2895425.0  2.414262e+06
# 2  https://d-portal.org/q.html?aid=41AAA-11295-032   514886.0  4.220031e+05
# 3  https://d-portal.org/q.html?aid=41AAA-11960-007  1668446.0  1.491148e+06
# 4  https://d-portal.org/q.html?aid=41AAA-20431-001  9475434.0  8.941619e+06
#
#     value_local      country iso_alpha2  country_id  time_id reporting_org_id
# 0  2.032183e+08  Afghanistan         AF           1    185.0              NaN
# 1  2.012126e+08  Afghanistan         AF           1    193.0              NaN
# 2  3.998347e+07  Afghanistan         AF           1    206.0              NaN
# 3  1.013080e+08  Afghanistan         AF           1    183.0              NaN
# 4  6.372229e+08  Afghanistan         AF           1    189.0              NaN
#
# [5 rows x 30 columns]

# %%
fact_iata = fact_iata.merge(
    dim_organization[[
        "organization_id",
        "organization_name",
        "organization_type_name"
    ]],
    left_on=["Provider Organisation", "Provider Organisation Type"],
    right_on=["organization_name", "organization_type_name"],
    how="left"
).rename(columns={"organization_id": "provider_org_id"})

fact_iata = fact_iata.drop(columns=["organization_name", "organization_type_name"])

# %%
fact_iata = fact_iata.merge(
    dim_organization[[
        "organization_id",
        "organization_name",
        "organization_type_name"
    ]],
    left_on=["Receiver Organisation", "Receiver Organisation Type"],
    right_on=["organization_name", "organization_type_name"],
    how="left"
).rename(columns={"organization_id": "receiving_org_id"})

fact_iata = fact_iata.drop(columns=["organization_name", "organization_type_name"])

# %%
dim_organization.head()
# Out:
#    organization_id                            organization_name_clean  \
# 0                1                                         UN-Habitat
# 1                2  United Nations Office for Project Services (UN...
# 2                3  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                4                         Gavi, the vaccine alliance
# 4                5     Swedish Committee for Afghanistan [AF-MOE-118]
#
#   organization_iati_id organization_type_code      organization_type_name  \
# 0                41120                     40                Multilateral
# 1                41AAA                     40                Multilateral
# 2                47045                     30  Public Private Partnership
# 3                47122                     40                Multilateral
# 4           AF-MOE-118                     21           International NGO
#
#                                    organization_name
# 0                                 UN-Habitat [41120]
# 1  United Nations Office for Project Services (UN...
# 2  The Global Fund to Fight AIDS, Tuberculosis an...
# 3                 Gavi, the vaccine alliance [47122]
# 4     Swedish Committee for Afghanistan [AF-MOE-118]
