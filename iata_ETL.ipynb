# %%
# import etl libraries
import requests
import pandas as pd, numpy as np 
from bs4 import BeautifulSoup

# %%
iata_data = pd.read_csv("data/country-development-finance/csv/iata_data.csv")

# %%
countries = iata_data["Recipient Country or Region"].unique()
countries
# Out:
# array(['AF - Afghanistan', 'BD - Bangladesh',
#        'BO - Bolivia (Plurinational State of)', 'CO - Colombia',
#        'EG - Egypt', 'ET - Ethiopia',
#        'GB - United Kingdom of Great Britain and Northern Ireland (the)',
#        'GE - Georgia', 'GH - Ghana', 'GT - Guatemala', 'HN - Honduras',
#        'HT - Haiti', 'JO - Jordan', 'KE - Kenya', 'KH - Cambodia',
#        'LB - Lebanon', 'MD - Moldova (the Republic of)', 'NG - Nigeria',
#        'NI - Nicaragua', 'NP - Nepal', 'PH - Philippines (the)',
#        'PK - Pakistan', 'RW - Rwanda', 'SL - Sierra Leone',
#        'SN - Senegal', 'TZ - Tanzania, the United Republic of',
#        'UA - Ukraine', 'UG - Uganda',
#        'US - United States of America (the)', 'VN - Viet Nam',
#        'YE - Yemen'], dtype=object)
